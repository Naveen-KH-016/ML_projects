# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Process
#
# - import dataset
# - drop unnecessary columns
# - transform categorical into numerical
# - train test split
# - scaling
# - training by linear regression
# - calculate accuracy

# %%
df=pd.read_csv('CarPrice_Assignment.csv')

# %%
df.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
# 5        sedan        fwd          front       99.8  ...         136
# 6        sedan        fwd          front      105.8  ...         136
# 7        wagon        fwd          front      105.8  ...         136
# 8        sedan        fwd          front      105.8  ...         131
# 9    hatchback        4wd          front       99.5  ...         131
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
# 5        mpfi       3.19    3.40              8.5        110     5500      19
# 6        mpfi       3.19    3.40              8.5        110     5500      19
# 7        mpfi       3.19    3.40              8.5        110     5500      19
# 8        mpfi       3.13    3.40              8.3        140     5500      17
# 9        mpfi       3.13    3.40              7.0        160     5500      16
#
#    highwaympg      price
# 0          27  13495.000
# 1          27  16500.000
# 2          26  16500.000
# 3          30  13950.000
# 4          22  17450.000
# 5          25  15250.000
# 6          25  17710.000
# 7          25  18920.000
# 8          20  23875.000
# 9          22  17859.167
#
# [10 rows x 26 columns]

# %%
df.shape
# Out:
# (205, 26)

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# #### dropping unnecessary columns

# %%
df=df.drop(columns=['car_ID','symboling','CarName'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fueltype          205 non-null    object
#  1   aspiration        205 non-null    object
#  2   doornumber        205 non-null    object
#  3   carbody           205 non-null    object
#  4   drivewheel        205 non-null    object
#  5   enginelocation    205 non-null    object
#  6   wheelbase         205 non-null    float64
#  7   carlength         205 non-null    float64
#  8   carwidth          205 non-null    float64
#  9   carheight         205 non-null    float64
#  10  curbweight        205 non-null    int64
#  11  enginetype        205 non-null    object
#  12  cylindernumber    205 non-null    object
#  13  enginesize        205 non-null    int64
#  14  fuelsystem        205 non-null    object
#  15  boreratio         205 non-null    float64
#  16  stroke            205 non-null    float64
#  17  compressionratio  205 non-null    float64
#  18  horsepower        205 non-null    int64
#  19  peakrpm           205 non-null    int64
#  20  citympg           205 non-null    int64
#  21  highwaympg        205 non-null    int64
#  22  price             205 non-null    float64
# dtypes: float64(8), int64(6), object(9)
# memory usage: 37.0+ KB

# %% [markdown]
# ### converting float to int

# %%
df['boreratio'] = df['boreratio'].astype(int)
df['stroke'] = df['stroke'].astype(int)
df['compressionratio'] = df['compressionratio'].astype(int)
df['price'] = df['price'].astype(int)
df['wheelbase'] = df['wheelbase'].astype(int)
df['carlength'] = df['carlength'].astype(int)
df['carwidth'] = df['carwidth'].astype(int)
df['carheight'] = df['carheight'].astype(int)

# %%
df.fuelsystem.value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
df.isnull().sum()
# Out:
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df=df.drop(columns=['fuelsystem'])

# %%
df.enginetype.value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
df=df.drop(columns=['enginetype'])

# %%
df.cylindernumber.value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
df=df.drop(columns=['cylindernumber'])

# %%
df.enginelocation.value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
for i in range(0,205):
    if df['enginelocation'][i]=="front":
        df['enginelocation'][i]=1
    else:
        df['enginelocation'][i]=0
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\2865313806.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['enginelocation'][i]=1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\2865313806.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['enginelocation'][i]=0

# %%
df.head(10)
# Out:
#   fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0      gas        std        two  convertible        rwd              1
# 1      gas        std        two  convertible        rwd              1
# 2      gas        std        two    hatchback        rwd              1
# 3      gas        std       four        sedan        fwd              1
# 4      gas        std       four        sedan        4wd              1
# 5      gas        std        two        sedan        fwd              1
# 6      gas        std       four        sedan        fwd              1
# 7      gas        std       four        wagon        fwd              1
# 8      gas      turbo       four        sedan        fwd              1
# 9      gas      turbo        two    hatchback        4wd              1
#
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88        168        64         48        2548         130
# 1         88        168        64         48        2548         130
# 2         94        171        65         52        2823         152
# 3         99        176        66         54        2337         109
# 4         99        176        66         54        2824         136
# 5         99        177        66         53        2507         136
# 6        105        192        71         55        2844         136
# 7        105        192        71         55        2954         136
# 8        105        192        71         55        3086         131
# 9         99        178        67         52        3053         131
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0          3       2                 9         111     5000       21
# 1          3       2                 9         111     5000       21
# 2          2       3                 9         154     5000       19
# 3          3       3                10         102     5500       24
# 4          3       3                 8         115     5500       18
# 5          3       3                 8         110     5500       19
# 6          3       3                 8         110     5500       19
# 7          3       3                 8         110     5500       19
# 8          3       3                 8         140     5500       17
# 9          3       3                 7         160     5500       16
#
#    highwaympg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          22  17859

# %% [markdown]
# ### transforming categorical to numerical

# %%
for i in range(0,205):
    if df['drivewheel'][i]=="fwd":
        df['drivewheel'][i]=1
    elif (df['drivewheel']=="4wd").any():
        df['drivewheel'][i]=0
    else:
        df['drivewheel'][i]=2
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\423740658.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drivewheel'][i]=0
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\423740658.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drivewheel'][i]=1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\423740658.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drivewheel'][i]=2

# %%
df['drivewheel'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 200    2
# 201    2
# 202    2
# 203    2
# 204    2
# Name: drivewheel, Length: 205, dtype: object>

# %%
df=df.drop(columns=['carbody','aspiration'])

# %%
df.doornumber.value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
for i in range(0,205):
    if df['doornumber'][i]=="four":
        df['doornumber'][i]=1
    else:
        df['doornumber'][i]=0
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\764286454.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['doornumber'][i]=0
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\764286454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['doornumber'][i]=1

# %%
df['doornumber']
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 200    1
# 201    1
# 202    1
# 203    1
# 204    1
# Name: doornumber, Length: 205, dtype: object

# %%
df.fueltype.value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
for i in range(0,205):
    if df['fueltype'][i]=="gas":
        df['fueltype'][i]=1
    else:
        df['fueltype'][i]=0
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\2445074868.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fueltype'][i]=1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8420\2445074868.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fueltype'][i]=0

# %%
df['fueltype']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 200    1
# 201    1
# 202    1
# 203    0
# 204    1
# Name: fueltype, Length: 205, dtype: object

# %%
df.head(10)
# Out:
#   fueltype doornumber drivewheel enginelocation  wheelbase  carlength  \
# 0        1          0          0              1         88        168
# 1        1          0          0              1         88        168
# 2        1          0          0              1         94        171
# 3        1          1          1              1         99        176
# 4        1          1          0              1         99        176
# 5        1          0          1              1         99        177
# 6        1          1          1              1        105        192
# 7        1          1          1              1        105        192
# 8        1          1          1              1        105        192
# 9        1          0          0              1         99        178
#
#    carwidth  carheight  curbweight  enginesize  boreratio  stroke  \
# 0        64         48        2548         130          3       2
# 1        64         48        2548         130          3       2
# 2        65         52        2823         152          2       3
# 3        66         54        2337         109          3       3
# 4        66         54        2824         136          3       3
# 5        66         53        2507         136          3       3
# 6        71         55        2844         136          3       3
# 7        71         55        2954         136          3       3
# 8        71         55        3086         131          3       3
# 9        67         52        3053         131          3       3
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg  price
# 0                 9         111     5000       21          27  13495
# 1                 9         111     5000       21          27  16500
# 2                 9         154     5000       19          26  16500
# 3                10         102     5500       24          30  13950
# 4                 8         115     5500       18          22  17450
# 5                 8         110     5500       19          25  15250
# 6                 8         110     5500       19          25  17710
# 7                 8         110     5500       19          25  18920
# 8                 8         140     5500       17          20  23875
# 9                 7         160     5500       16          22  17859

# %%
x=df.iloc[:,0:-1]

# %%
x
# Out:
#     fueltype doornumber drivewheel enginelocation  wheelbase  carlength  \
# 0          1          0          0              1         88        168
# 1          1          0          0              1         88        168
# 2          1          0          0              1         94        171
# 3          1          1          1              1         99        176
# 4          1          1          0              1         99        176
# ..       ...        ...        ...            ...        ...        ...
# 200        1          1          2              1        109        188
# 201        1          1          2              1        109        188
# 202        1          1          2              1        109        188
# 203        0          1          2              1        109        188
# 204        1          1          2              1        109        188
#
#      carwidth  carheight  curbweight  enginesize  boreratio  stroke  \
# 0          64         48        2548         130          3       2
# 1          64         48        2548         130          3       2
# 2          65         52        2823         152          2       3
# 3          66         54        2337         109          3       3
# 4          66         54        2824         136          3       3
# ..        ...        ...         ...         ...        ...     ...
# 200        68         55        2952         141          3       3
# 201        68         55        3049         141          3       3
# 202        68         55        3012         173          3       2
# 203        68         55        3217         145          3       3
# 204        68         55        3062         141          3       3
#
#      compressionratio  horsepower  peakrpm  citympg  highwaympg
# 0                   9         111     5000       21          27
# 1                   9         111     5000       21          27
# 2                   9         154     5000       19          26
# 3                  10         102     5500       24          30
# 4                   8         115     5500       18          22
# ..                ...         ...      ...      ...         ...
# 200                 9         114     5400       23          28
# 201                 8         160     5300       19          25
# 202                 8         134     5500       18          23
# 203                23         106     4800       26          27
# 204                 9         114     5400       19          25
#
# [205 rows x 17 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: int32

# %% [markdown]
# #### train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_test
# Out:
#     fueltype doornumber drivewheel enginelocation  wheelbase  carlength  \
# 15         1          1          0              1        103        189
# 9          1          0          0              1         99        178
# 100        1          1          1              1         97        173
# 132        1          0          1              1         99        186
# 68         0          1          0              1        110        190
# ..       ...        ...        ...            ...        ...        ...
# 56         1          0          0              1         95        169
# 128        1          0          0              0         89        168
# 76         1          0          1              1         93        157
# 144        1          1          0              1         97        172
# 104        1          0          0              1         91        170
#
#      carwidth  carheight  curbweight  enginesize  boreratio  stroke  \
# 15         66         55        3230         209          3       3
# 9          67         52        3053         131          3       3
# 100        65         54        2302         120          3       3
# 132        66         56        2658         121          3       3
# 68         70         58        3750         183          3       3
# ..        ...        ...         ...         ...        ...     ...
# 56         65         49        2380          70          3       3
# 128        65         51        2800         194          3       2
# 76         64         50        1918          92          2       3
# 144        65         54        2385         108          3       2
# 104        67         49        3071         181          3       3
#
#      compressionratio  horsepower  peakrpm  citympg  highwaympg
# 15                  8         182     5400       16          22
# 9                   7         160     5500       16          22
# 100                 8          97     5200       27          34
# 132                 9         110     5250       21          28
# 68                 21         123     4350       22          25
# ..                ...         ...      ...      ...         ...
# 56                  9         101     6000       17          23
# 128                 9         207     5900       17          25
# 76                  9          68     5500       37          41
# 144                 9          82     4800       24          25
# 104                 9         160     5200       19          25
#
# [62 rows x 17 columns]

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_scaled=scaler.fit_transform(x_train)

# %%
x_test_scaled=scaler.fit_transform(x_test)

# %%
x_test_scaled
# Out:
# array([[ 0.38490018,  0.87831007, -1.34913081, ...,  0.76952735,
#         -1.31581608, -1.20210967],
#        [ 0.38490018, -1.13855009, -1.34913081, ...,  0.99404827,
#         -1.31581608, -1.20210967],
#        [ 0.38490018,  0.87831007,  0.290989  , ...,  0.32048551,
#          0.11087163,  0.27863469],
#        ...,
#        [ 0.38490018, -1.13855009,  0.290989  , ...,  0.99404827,
#          1.40786045,  1.14240223],
#        [ 0.38490018,  0.87831007, -1.34913081, ..., -0.57759818,
#         -0.27822502, -0.83192358],
#        [ 0.38490018, -1.13855009, -1.34913081, ...,  0.32048551,
#         -0.92671943, -0.83192358]])

# %% [markdown]
# ### Applying Linear Regression because data has linear behaviour

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.851871578667877

# %% [markdown]
# ### Got 85.5% accuracy
