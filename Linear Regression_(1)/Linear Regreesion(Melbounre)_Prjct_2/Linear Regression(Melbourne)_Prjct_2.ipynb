# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor

# %%
import plotly.express as px

# %% [markdown]
# # Load Housing Prediction Data from csv file

# %%
data = pd.read_csv('Melbourne_housing_FULL.CSV')

# %% [markdown]
# Suburb: Suburb
#
# Address: Address
#
# Rooms: Number of rooms
#
# Price: Price in Australian dollars
#
# Method: S - property sold; SP - property sold prior; PI - property passed in; PN - sold prior not disclosed; SN - sold not disclosed; NB - no bid; VB - vendor bid; W - withdrawn prior to auction; SA - sold after auction; SS - sold after auction price not disclosed. N/A - price or highest bid not available.
#
# Type: br - bedroom(s); h - house,cottage,villa, semi,terrace; u - unit, duplex; t - townhouse; dev site - development site; o res - other residential.
#
# SellerG: Real Estate Agent
#
# Date: Date sold
#
# Distance: Distance from CBD in Kilometres
#
# Regionname: General Region (West, North West, North, North east ...etc)
#
# Propertycount: Number of properties that exist in the suburb.
#
# Bedroom2 : Scraped # of Bedrooms (from different source)
#
# Bathroom: Number of Bathrooms
#
# Car: Number of carspots
#
# Landsize: Land Size in Metres
#
# BuildingArea: Building Size in Metres
#
# YearBuilt: Year the house was built
#
# CouncilArea: Governing council for the area
#
# Lattitude: Self explanitory
#
# Longtitude: Self explanitory
#
# Postcode: Postal Code

# %% [markdown]
# ## Let's have a look at shape of the dataframe

# %%
data.shape
# Out:
# (34857, 21)

# %% [markdown]
# ## Let's look at column names in dataset

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# ## Check if all records have "Price". Filter records with "Price" and take that as training set.

# %%
data.Price.count() # Some historic records have missing values in target variable
# Out:
# 27247

# %%
data_no_nulls_in_target = data[~ data.Price.isnull() ] ## Eliminated records"

# %%
data_no_nulls_in_target.shape
# Out:
# (27247, 21)

# %%
def msv_1(data, thresh = 10, color = 'black', edgecolor = 'black', height = 3, width = 15):
    
    plt.figure(figsize = (width, height))
    percentage = (data.isnull().mean()) * 100
    percentage.sort_values(ascending = False).plot.bar(color = color, edgecolor = edgecolor)
    plt.axhline(y = thresh, color = 'b', linestyle = '-')
    
    plt.title('Missing values percentage per column', fontsize=20, weight='bold' )
    
    plt.text(len(data.isnull().sum()/len(data))/1.7, thresh+2.5, f'Columns with more than {thresh}% missing values', fontsize=12, color='crimson',
         ha='left' ,va='top')
    plt.text(len(data.isnull().sum()/len(data))/1.7, thresh - 0.5, f'Columns with less than {thresh}% missing values', fontsize=12, color='green',
         ha='left' ,va='top')
    plt.xlabel('Columns', size=15, weight='bold')
    plt.ylabel('Missing values percentage')
    plt.yticks(weight ='bold')
    
    return plt.show()
msv_1(data, 20, color=sns.color_palette('Reds',15))

# %%
data_no_nulls_in_target.reset_index(drop=True, inplace=True)

# %%
data_no_nulls_in_target.to_csv(index=False, path_or_buf='./Melbourne_housing_FULL')

# %%
from sklearn.model_selection import ShuffleSplit
shuffleSplit = ShuffleSplit(n_splits=1,test_size = 0.2 , random_state=42)

for train_index, test_index in shuffleSplit.split(data_no_nulls_in_target):
    training_set = data_no_nulls_in_target.loc[train_index]
    test_set = data_no_nulls_in_target.loc[test_index]

# %% [markdown]
# ## Just to get an idea, let's have a look at first 5 records

# %%
training_set.head()
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 17957  Brunswick East    2/20 Lyndhurst Cr      2    u   580000.0     VB
# 6753         Richmond        21 Lambert St      3    t  1025000.0     SP
# 1833   Brunswick West     11/7 Egginton St      2    t   380000.0     VB
# 19795     Pascoe Vale  3/246 Cumberland Rd      2    u   456000.0      S
# 17054   Glen Waverley         31 Paxton Dr      3    h  1300000.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 17957         Nelson  26/08/2017       4.0    3057.0  ...       1.0  1.0
# 6753          Jellis   3/12/2016       2.6    3121.0  ...       NaN  NaN
# 1833          Nelson   7/11/2016       5.9    3055.0  ...       1.0  1.0
# 19795           Brad  21/10/2017       8.5    3044.0  ...       NaN  NaN
# 17054  hockingstuart  19/08/2017      16.7    3150.0  ...       2.0  3.0
#
#        Landsize  BuildingArea  YearBuilt            CouncilArea Lattitude  \
# 17957       NaN          61.0     1970.0  Moreland City Council -37.76134
# 6753        NaN           NaN        NaN     Yarra City Council       NaN
# 1833        0.0          85.0     1970.0  Moreland City Council -37.76070
# 19795       NaN           NaN        NaN  Moreland City Council       NaN
# 17054     733.0           NaN        NaN    Monash City Council -37.89014
#
#        Longtitude             Regionname Propertycount
# 17957   144.97796  Northern Metropolitan        5533.0
# 6753          NaN  Northern Metropolitan       14949.0
# 1833    144.93930  Northern Metropolitan        7082.0
# 19795         NaN  Northern Metropolitan        7485.0
# 17054   145.18269   Eastern Metropolitan       15321.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Exploratory Data Analysis
#
# As part of data analysis we refine the data - below are some common activities we do.
#
# * Missing : Check for missing or incomplete data, impute/fillna with appropriate data
# * Quality : Check for duplicates, accuracy, unusual data.
# * Parse : Prase existing data and create new fearures. e.g. Extract year and month from date
# * Convert : Free text to coded value (LabelEncoder, One-Hot-Encoding or LabelBinarizer)
# * Derive: Derive new feature out of existing featre/fearues e.g. gender from title Mr. Mrs.
# * Calculate percentages, proportion
# * Remove: Remove redundant or not so useful data
# * Merge: Merge multiple columns e.g. first and surname for full name
# * Aggregate e.g. rollup by year, cluster by area
# * Filter e.g. exclude based on location
# * Sample e.g. extract a representative data
# * Summary Pandas describe function or stats like mean
#
# Check if any columns have got nulls

# %%
training_set.isnull().any()
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True
# dtype: bool

# %% [markdown]
# ## Look at distinct data types in our data

# %%
training_set.dtypes.value_counts()
# Out:
# float64    12
# object      8
# int64       1
# dtype: int64

# %% [markdown]
# ## Check if numerical columns have got nulls.
# * If we see below, most of the numerical columns have got nulls.
# * Some features like "Postcode", "Lattitude", and "Longtitude" are related features. These three reatures are related to "Address". I am thinking if we can use "Postcode" feature to represent all there.

# %%
training_set.select_dtypes(['float64','int64']).isnull().any()
# Out:
# Rooms            False
# Price            False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# Lattitude         True
# Longtitude        True
# Propertycount     True
# dtype: bool

# %% [markdown]
# # Check if categorical/text columns have got nulls.
# * "CouncilArea", "Regionname" have got nulls. These two reatures are related to "Address". I am thinking if we can use "Postcode" feature to represent all there.

# %%
training_set.select_dtypes(['object']).isnull().any()
# Out:
# Suburb         False
# Address        False
# Type           False
# Method         False
# SellerG        False
# Date           False
# CouncilArea     True
# Regionname      True
# dtype: bool

# %% [markdown]
# Big Decision (importance of Statistical Data Analysis - Bivariate data analysis):
# Should we remove "CouncilArea", "Regionname", "Lattitude", and "Longtitude" features and have "Postcode" or "Suburb" as it may represent the address - in other workds, we need to check if "Postcode" or "Suburb" an important feature in predicting "Price" ?
# * Before we make a decision we have to fix some problems with "Postcode" column by do some statistical data analysis
#
# - Step 1: Check "Postcode" equal for all the addresses in same "Suburb" (a column with no-nulls). If so, we can write some logic to populate "Postcode" based on "Suburb".
# - Step 2: Is "Postcode", "Suburb" an important feature to predict "Price" ?.

# %%
df_null_postcodes = training_set[training_set['Postcode'].isnull()]

# %%
df_null_postcodes
# Out:
#             Suburb       Address  Rooms Type     Price Method SellerG  \
# 23051  Fawkner Lot  1/3 Brian St      3    h  616000.0     SP    Brad
#
#             Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 23051  6/01/2018       NaN       NaN  ...       NaN  NaN       NaN
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  Regionname  \
# 23051           NaN        NaN          NaN       NaN         NaN         NaN
#
#       Propertycount
# 23051           NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# Check if any row with non-null "Suburb" is present for row in "Postcode"

# %%
df_null_postcodes[~ df_null_postcodes['Suburb'].isnull()]
# Out:
#             Suburb       Address  Rooms Type     Price Method SellerG  \
# 23051  Fawkner Lot  1/3 Brian St      3    h  616000.0     SP    Brad
#
#             Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 23051  6/01/2018       NaN       NaN  ...       NaN  NaN       NaN
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  Regionname  \
# 23051           NaN        NaN          NaN       NaN         NaN         NaN
#
#       Propertycount
# 23051           NaN
#
# [1 rows x 21 columns]

# %%
training_set = training_set[~ training_set['Postcode'].isnull()]

# %%
training_set.shape
# Out:
# (21796, 21)

# %% [markdown]
# Check if distict "Suburb" have distict "Postcode"

# %%
training_set['Suburb'].value_counts().shape
# Out:
# (337,)

# %%
training_set['Postcode'].value_counts().shape
# Out:
# (205,)

# %%
ser_postcode_suburb = training_set.groupby(['Postcode', 'Suburb']).size()

# %%
type(ser_postcode_suburb)
# Out:
# pandas.core.series.Series

# %%
ser_postcode_suburb.head(30)
# Out:
# Postcode  Suburb
# 3000.0    Melbourne             117
# 3002.0    East Melbourne         30
# 3003.0    West Melbourne         37
# 3006.0    Southbank              46
# 3008.0    Docklands               6
# 3011.0    Footscray             168
#           Seddon                 76
# 3012.0    Brooklyn               31
#           Kingsville             50
#           Maidstone             118
#           West Footscray        128
# 3013.0    Yarraville            194
# 3015.0    Newport               168
#           South Kingsville       24
#           Spotswood              38
# 3016.0    Williamstown          140
#           Williamstown North     19
# 3018.0    Altona                 87
#           Seaholme               17
# 3019.0    Braybrook              64
# 3020.0    Albion                 53
#           Sunshine              137
#           Sunshine North         97
#           Sunshine West         131
# 3021.0    Albanvale               7
#           Kealba                 32
#           Kings Park             10
#           St Albans              80
# 3022.0    Ardeer                 17
# 3023.0    Burnside                4
# dtype: int64

# %%
df_postcode_suburb = training_set.groupby(['Postcode', 'Suburb']).size().reset_index(name='count')

# %%
df_postcode_suburb.head(20)
# Out:
#     Postcode              Suburb  count
# 0     3000.0           Melbourne    117
# 1     3002.0      East Melbourne     30
# 2     3003.0      West Melbourne     37
# 3     3006.0           Southbank     46
# 4     3008.0           Docklands      6
# 5     3011.0           Footscray    168
# 6     3011.0              Seddon     76
# 7     3012.0            Brooklyn     31
# 8     3012.0          Kingsville     50
# 9     3012.0           Maidstone    118
# 10    3012.0      West Footscray    128
# 11    3013.0          Yarraville    194
# 12    3015.0             Newport    168
# 13    3015.0    South Kingsville     24
# 14    3015.0           Spotswood     38
# 15    3016.0        Williamstown    140
# 16    3016.0  Williamstown North     19
# 17    3018.0              Altona     87
# 18    3018.0            Seaholme     17
# 19    3019.0           Braybrook     64

# %%
for postcode , group in df_postcode_suburb.groupby(['Postcode']):
    print("Postcode = %s" %(postcode))
    print(25*'*')
    print(group[['Suburb', 'count']])
    print(50*'-')
# Out:
# Postcode = 3000.0
# *************************
#       Suburb  count
# 0  Melbourne    117
# --------------------------------------------------
# Postcode = 3002.0
# *************************
#            Suburb  count
# 1  East Melbourne     30
# --------------------------------------------------
# Postcode = 3003.0
# *************************
#            Suburb  count
# 2  West Melbourne     37
# --------------------------------------------------
# Postcode = 3006.0
# *************************
#       Suburb  count
# 3  Southbank     46
# --------------------------------------------------
# Postcode = 3008.0
# *************************
#       Suburb  count
# 4  Docklands      6
# --------------------------------------------------
# Postcode = 3011.0
# *************************
#       Suburb  count
# 5  Footscray    168
# 6     Seddon     76
# --------------------------------------------------
# Postcode = 3012.0
# *************************
#             Suburb  count
# 7         Brooklyn     31
# 8       Kingsville     50
# 9        Maidstone    118
# 10  West Footscray    128
# --------------------------------------------------
# Postcode = 3013.0
# *************************
#         Suburb  count
# 11  Yarraville    194
# --------------------------------------------------
# Postcode = 3015.0
# *************************
#               Suburb  count
# 12           Newport    168
# 13  South Kingsville     24
# 14         Spotswood     38
# --------------------------------------------------
# Postcode = 3016.0
# *************************
#                 Suburb  count
# 15        Williamstown    140
# 16  Williamstown North     19
# --------------------------------------------------
# Postcode = 3018.0
# *************************
#       Suburb  count
# 17    Altona     87
# 18  Seaholme     17
# --------------------------------------------------
# Postcode = 3019.0
# *************************
#        Suburb  count
# 19  Braybrook     64
# --------------------------------------------------
# Postcode = 3020.0
# *************************
#             Suburb  count
# 20          Albion     53
# 21        Sunshine    137
# 22  Sunshine North     97
# 23   Sunshine West    131
# --------------------------------------------------
# Postcode = 3021.0
# *************************
#         Suburb  count
# 24   Albanvale      7
# 25      Kealba     32
# 26  Kings Park     10
# 27   St Albans     80
# --------------------------------------------------
# Postcode = 3022.0
# *************************
#     Suburb  count
# 28  Ardeer     17
# --------------------------------------------------
# Postcode = 3023.0
# *************************
#               Suburb  count
# 29          Burnside      4
# 30  Burnside Heights      9
# 31          Cairnlea     15
# 32  Caroline Springs     20
# 33         Deer Park     31
# --------------------------------------------------
# Postcode = 3024.0
# *************************
#           Suburb  count
# 34  Wyndham Vale     42
# --------------------------------------------------
# Postcode = 3025.0
# *************************
#           Suburb  count
# 35  Altona North    118
# --------------------------------------------------
# Postcode = 3027.0
# *************************
#               Suburb  count
# 36  Williams Landing      5
# --------------------------------------------------
# Postcode = 3028.0
# *************************
#             Suburb  count
# 37  Altona Meadows     21
# 38        Laverton      6
# 39        Seabrook      3
# --------------------------------------------------
# Postcode = 3029.0
# *************************
#               Suburb  count
# 40  Hoppers Crossing    107
# 41           Tarneit     29
# 42         Truganina     18
# --------------------------------------------------
# Postcode = 3030.0
# *************************
#             Suburb  count
# 43        Derrimut     14
# 44      Point Cook     68
# 45        Werribee    120
# 46  Werribee South      2
# --------------------------------------------------
# Postcode = 3031.0
# *************************
#         Suburb  count
# 47  Flemington     80
# 48  Kensington    150
# --------------------------------------------------
# Postcode = 3032.0
# *************************
#          Suburb  count
# 49   Ascot Vale    167
# 50  Maribyrnong    146
# 51   Travancore     10
# --------------------------------------------------
# Postcode = 3033.0
# *************************
#          Suburb  count
# 52  Keilor East    172
# --------------------------------------------------
# Postcode = 3034.0
# *************************
#               Suburb  count
# 53  Avondale Heights    117
# --------------------------------------------------
# Postcode = 3036.0
# *************************
#     Suburb  count
# 54  Keilor     13
# --------------------------------------------------
# Postcode = 3037.0
# *************************
#           Suburb  count
# 55       Delahey     17
# 56      Hillside     54
# 57      Sydenham     21
# 58  Taylors Hill     28
# --------------------------------------------------
# Postcode = 3038.0
# *************************
#            Suburb  count
# 59   Keilor Downs     35
# 60   Keilor Lodge      5
# 61  Taylors Lakes     51
# --------------------------------------------------
# Postcode = 3039.0
# *************************
#           Suburb  count
# 62  Moonee Ponds    201
# --------------------------------------------------
# Postcode = 3040.0
# *************************
#            Suburb  count
# 63     Aberfeldie     58
# 64       Essendon    291
# 65  Essendon West     31
# --------------------------------------------------
# Postcode = 3041.0
# *************************
#                 Suburb  count
# 66      Essendon North     33
# 67          Strathmore    115
# 68  Strathmore Heights     11
# --------------------------------------------------
# Postcode = 3042.0
# *************************
#           Suburb  count
# 69  Airport West    125
# 70   Keilor Park     29
# 71       Niddrie    100
# --------------------------------------------------
# Postcode = 3043.0
# *************************
#             Suburb  count
# 72  Gladstone Park     44
# 73       Gowanbrae     33
# 74     Tullamarine     41
# --------------------------------------------------
# Postcode = 3044.0
# *************************
#          Suburb  count
# 75  Pascoe Vale    253
# --------------------------------------------------
# Postcode = 3046.0
# *************************
#       Suburb  count
# 76   Glenroy    275
# 77  Hadfield     66
# 78  Oak Park     87
# --------------------------------------------------
# Postcode = 3047.0
# *************************
#           Suburb  count
# 79  Broadmeadows     62
# 80        Dallas     27
# 81        Jacana     44
# --------------------------------------------------
# Postcode = 3048.0
# *************************
#             Suburb  count
# 82        Coolaroo      7
# 83  Meadow Heights     38
# --------------------------------------------------
# Postcode = 3049.0
# *************************
#          Suburb  count
# 84      Attwood     12
# 85  Westmeadows     33
# --------------------------------------------------
# Postcode = 3051.0
# *************************
#              Suburb  count
# 86  North Melbourne     95
# --------------------------------------------------
# Postcode = 3052.0
# *************************
#        Suburb  count
# 87  Parkville     42
# --------------------------------------------------
# Postcode = 3053.0
# *************************
#      Suburb  count
# 88  Carlton     57
# --------------------------------------------------
# Postcode = 3054.0
# *************************
#            Suburb  count
# 89  Carlton North     57
# 90   Princes Hill     10
# --------------------------------------------------
# Postcode = 3055.0
# *************************
#             Suburb  count
# 91  Brunswick West    169
# --------------------------------------------------
# Postcode = 3056.0
# *************************
#        Suburb  count
# 92  Brunswick    323
# --------------------------------------------------
# Postcode = 3057.0
# *************************
#             Suburb  count
# 93  Brunswick East    127
# --------------------------------------------------
# Postcode = 3058.0
# *************************
#           Suburb  count
# 94        Coburg    243
# 95  Coburg North     99
# --------------------------------------------------
# Postcode = 3059.0
# *************************
#        Suburb  count
# 96  Greenvale     63
# --------------------------------------------------
# Postcode = 3060.0
# *************************
#      Suburb  count
# 97  Fawkner    125
# --------------------------------------------------
# Postcode = 3061.0
# *************************
#            Suburb  count
# 98  Campbellfield     15
# --------------------------------------------------
# Postcode = 3064.0
# *************************
#             Suburb  count
# 99     Craigieburn    168
# 100       Kalkallo      1
# 101      Mickleham      7
# 102  Roxburgh Park     66
# --------------------------------------------------
# Postcode = 3065.0
# *************************
#       Suburb  count
# 103  Fitzroy     87
# --------------------------------------------------
# Postcode = 3066.0
# *************************
#           Suburb  count
# 104  Collingwood     69
# --------------------------------------------------
# Postcode = 3067.0
# *************************
#          Suburb  count
# 105  Abbotsford     84
# --------------------------------------------------
# Postcode = 3068.0
# *************************
#             Suburb  count
# 106   Clifton Hill     91
# 107  Fitzroy North    119
# --------------------------------------------------
# Postcode = 3070.0
# *************************
#         Suburb  count
# 108  Northcote    270
# --------------------------------------------------
# Postcode = 3071.0
# *************************
#         Suburb  count
# 109  Thornbury    215
# --------------------------------------------------
# Postcode = 3072.0
# *************************
#       Suburb  count
# 110  Preston    332
# --------------------------------------------------
# Postcode = 3073.0
# *************************
#         Suburb  count
# 111  Reservoir    592
# --------------------------------------------------
# Postcode = 3074.0
# *************************
#          Suburb  count
# 112  Thomastown     70
# --------------------------------------------------
# Postcode = 3075.0
# *************************
#     Suburb  count
# 113  Lalor     67
# --------------------------------------------------
# Postcode = 3076.0
# *************************
#      Suburb  count
# 114  Epping    122
# --------------------------------------------------
# Postcode = 3078.0
# *************************
#          Suburb  count
# 115  Alphington     52
# 116   Fairfield     57
# --------------------------------------------------
# Postcode = 3079.0
# *************************
#            Suburb  count
# 117       Ivanhoe    136
# 118  Ivanhoe East     38
# --------------------------------------------------
# Postcode = 3081.0
# *************************
#                  Suburb  count
# 119           Bellfield     21
# 120  Heidelberg Heights     97
# 121     Heidelberg West     87
# --------------------------------------------------
# Postcode = 3082.0
# *************************
#         Suburb  count
# 122  Mill Park    116
# --------------------------------------------------
# Postcode = 3083.0
# *************************
#         Suburb  count
# 123   Bundoora    111
# 124  Kingsbury     34
# --------------------------------------------------
# Postcode = 3084.0
# *************************
#          Suburb  count
# 125   Eaglemont     28
# 126  Heidelberg     63
# 127     Rosanna    105
# 128    Viewbank     56
# 129    viewbank      1
# --------------------------------------------------
# Postcode = 3085.0
# *************************
#         Suburb  count
# 130    MacLeod     53
# 131  Yallambie     36
# --------------------------------------------------
# Postcode = 3087.0
# *************************
#              Suburb  count
# 132        Watsonia     67
# 133  Watsonia North     21
# --------------------------------------------------
# Postcode = 3088.0
# *************************
#             Suburb  count
# 134     Briar Hill     16
# 135  Greensborough     90
# 136      St Helena      9
# --------------------------------------------------
# Postcode = 3089.0
# *************************
#             Suburb  count
# 137  Diamond Creek     19
# --------------------------------------------------
# Postcode = 3093.0
# *************************
#            Suburb  count
# 138  Lower Plenty     17
# --------------------------------------------------
# Postcode = 3094.0
# *************************
#           Suburb  count
# 139  Montmorency     48
# --------------------------------------------------
# Postcode = 3095.0
# *************************
#            Suburb  count
# 140        Eltham     61
# 141  Eltham North     16
# 142      Research      4
# --------------------------------------------------
# Postcode = 3096.0
# *************************
#           Suburb  count
# 143  Wattle Glen      1
# --------------------------------------------------
# Postcode = 3099.0
# *************************
#           Suburb  count
# 144  Hurstbridge      2
# --------------------------------------------------
# Postcode = 3101.0
# *************************
#     Suburb  count
# 145    Kew    264
# --------------------------------------------------
# Postcode = 3102.0
# *************************
#        Suburb  count
# 146  Kew East     77
# --------------------------------------------------
# Postcode = 3103.0
# *************************
#        Suburb  count
# 147    Balwyn    187
# 148  Deepdene      6
# --------------------------------------------------
# Postcode = 3104.0
# *************************
#            Suburb  count
# 149  Balwyn North    245
# --------------------------------------------------
# Postcode = 3105.0
# *************************
#       Suburb  count
# 150  Bulleen    106
# --------------------------------------------------
# Postcode = 3106.0
# *************************
#           Suburb  count
# 151  Templestowe     54
# --------------------------------------------------
# Postcode = 3107.0
# *************************
#                 Suburb  count
# 152  Templestowe Lower    141
# --------------------------------------------------
# Postcode = 3108.0
# *************************
#         Suburb  count
# 153  Doncaster    164
# --------------------------------------------------
# Postcode = 3109.0
# *************************
#              Suburb  count
# 154  Doncaster East     95
# --------------------------------------------------
# Postcode = 3111.0
# *************************
#       Suburb  count
# 155  Donvale     34
# --------------------------------------------------
# Postcode = 3113.0
# *************************
#                Suburb  count
# 156  North Warrandyte      5
# 157        Warrandyte      8
# --------------------------------------------------
# Postcode = 3115.0
# *************************
#          Suburb  count
# 158  Wonga Park      2
# --------------------------------------------------
# Postcode = 3116.0
# *************************
#              Suburb  count
# 159  Chirnside Park      8
# --------------------------------------------------
# Postcode = 3121.0
# *************************
#        Suburb  count
# 160   Burnley     10
# 161  Cremorne     31
# 162  Richmond    349
# --------------------------------------------------
# Postcode = 3122.0
# *************************
#        Suburb  count
# 163  Hawthorn    253
# --------------------------------------------------
# Postcode = 3123.0
# *************************
#             Suburb  count
# 164  Hawthorn East    159
# --------------------------------------------------
# Postcode = 3124.0
# *************************
#          Suburb  count
# 165  Camberwell    222
# --------------------------------------------------
# Postcode = 3125.0
# *************************
#       Suburb  count
# 166  Burwood    131
# --------------------------------------------------
# Postcode = 3126.0
# *************************
#          Suburb  count
# 167  Canterbury     67
# --------------------------------------------------
# Postcode = 3127.0
# *************************
#            Suburb  count
# 168   Mont Albert     63
# 169  Surrey Hills    162
# --------------------------------------------------
# Postcode = 3128.0
# *************************
#        Suburb  count
# 170  Box Hill     67
# --------------------------------------------------
# Postcode = 3130.0
# *************************
#               Suburb  count
# 171        Blackburn     49
# 172  Blackburn North     30
# 173  Blackburn South     32
# --------------------------------------------------
# Postcode = 3131.0
# *************************
#           Suburb  count
# 174  Forest Hill     44
# 175   Nunawading     41
# --------------------------------------------------
# Postcode = 3132.0
# *************************
#       Suburb  count
# 176  Mitcham     75
# --------------------------------------------------
# Postcode = 3133.0
# *************************
#             Suburb  count
# 177        Vermont     30
# 178  Vermont South     27
# --------------------------------------------------
# Postcode = 3134.0
# *************************
#              Suburb  count
# 179        Ringwood     44
# 180  Ringwood North     23
# 181      Warranwood      3
# --------------------------------------------------
# Postcode = 3135.0
# *************************
#             Suburb  count
# 182      Heathmont     32
# 183  Ringwood East     27
# --------------------------------------------------
# Postcode = 3136.0
# *************************
#             Suburb  count
# 184        Croydon     83
# 185  Croydon Hills     11
# 186  Croydon North     16
# 187  Croydon South     10
# 188        croydon      1
# --------------------------------------------------
# Postcode = 3137.0
# *************************
#       Suburb  count
# 189  Kilsyth     17
# --------------------------------------------------
# Postcode = 3138.0
# *************************
#           Suburb  count
# 190  Mooroolbark     29
# --------------------------------------------------
# Postcode = 3140.0
# *************************
#        Suburb  count
# 191  Lilydale      4
# --------------------------------------------------
# Postcode = 3141.0
# *************************
#           Suburb  count
# 192  South Yarra    276
# --------------------------------------------------
# Postcode = 3142.0
# *************************
#      Suburb  count
# 193  Toorak    135
# --------------------------------------------------
# Postcode = 3143.0
# *************************
#        Suburb  count
# 194  Armadale    118
# --------------------------------------------------
# Postcode = 3144.0
# *************************
#       Suburb  count
# 195  Kooyong      5
# 196  Malvern    100
# --------------------------------------------------
# Postcode = 3145.0
# *************************
#              Suburb  count
# 197  Caulfield East     15
# 198    Malvern East    183
# --------------------------------------------------
# Postcode = 3146.0
# *************************
#         Suburb  count
# 199  Glen Iris    255
# --------------------------------------------------
# Postcode = 3147.0
# *************************
#         Suburb  count
# 200  Ashburton     90
# 201    Ashwood     83
# --------------------------------------------------
# Postcode = 3148.0
# *************************
#         Suburb  count
# 202  Chadstone     61
# --------------------------------------------------
# Postcode = 3149.0
# *************************
#              Suburb  count
# 203  Mount Waverley    135
# --------------------------------------------------
# Postcode = 3150.0
# *************************
#             Suburb  count
# 204  Glen Waverley    116
# 205  Wheelers Hill     52
# --------------------------------------------------
# Postcode = 3151.0
# *************************
#            Suburb  count
# 206  Burwood East     33
# --------------------------------------------------
# Postcode = 3152.0
# *************************
#              Suburb  count
# 207        Wantirna     35
# 208  Wantirna South     35
# --------------------------------------------------
# Postcode = 3153.0
# *************************
#               Suburb  count
# 209        Bayswater     27
# 210  Bayswater North     17
# --------------------------------------------------
# Postcode = 3154.0
# *************************
#         Suburb  count
# 211  The Basin      3
# --------------------------------------------------
# Postcode = 3155.0
# *************************
#       Suburb  count
# 212  Boronia     33
# --------------------------------------------------
# Postcode = 3156.0
# *************************
#              Suburb  count
# 213  Ferntree Gully     46
# 214     Lysterfield      1
# --------------------------------------------------
# Postcode = 3158.0
# *************************
#     Suburb  count
# 215  Upwey      2
# --------------------------------------------------
# Postcode = 3160.0
# *************************
#      Suburb  count
# 216  Tecoma      1
# --------------------------------------------------
# Postcode = 3161.0
# *************************
#               Suburb  count
# 217  Caulfield North     48
# --------------------------------------------------
# Postcode = 3162.0
# *************************
#               Suburb  count
# 218        Caulfield     14
# 219  Caulfield South     63
# --------------------------------------------------
# Postcode = 3163.0
# *************************
#           Suburb  count
# 220     Carnegie    183
# 221  Glen Huntly     40
# 222  Murrumbeena    110
# --------------------------------------------------
# Postcode = 3165.0
# *************************
#              Suburb  count
# 223  Bentleigh East    405
# --------------------------------------------------
# Postcode = 3166.0
# *************************
#             Suburb  count
# 224     Hughesdale     42
# 225    Huntingdale      7
# 226       Oakleigh     64
# 227  Oakleigh East     23
# --------------------------------------------------
# Postcode = 3167.0
# *************************
#              Suburb  count
# 228  Oakleigh South     87
# --------------------------------------------------
# Postcode = 3168.0
# *************************
#            Suburb  count
# 229       Clayton     31
# 230  Notting Hill      7
# --------------------------------------------------
# Postcode = 3169.0
# *************************
#             Suburb  count
# 231       Clarinda     12
# 232  Clayton South     29
# --------------------------------------------------
# Postcode = 3170.0
# *************************
#        Suburb  count
# 233  Mulgrave     64
# --------------------------------------------------
# Postcode = 3171.0
# *************************
#          Suburb  count
# 234  Springvale     26
# --------------------------------------------------
# Postcode = 3172.0
# *************************
#                Suburb  count
# 235   Dingley Village     36
# 236  Springvale South      8
# --------------------------------------------------
# Postcode = 3173.0
# *************************
#           Suburb  count
# 237  Keysborough     23
# --------------------------------------------------
# Postcode = 3174.0
# *************************
#          Suburb  count
# 238  Noble Park     41
# --------------------------------------------------
# Postcode = 3175.0
# *************************
#               Suburb  count
# 239        Dandenong     33
# 240  Dandenong North     33
# --------------------------------------------------
# Postcode = 3177.0
# *************************
#            Suburb  count
# 241       Doveton     15
# 242  Eumemmerring      1
# --------------------------------------------------
# Postcode = 3178.0
# *************************
#        Suburb  count
# 243  Rowville     25
# --------------------------------------------------
# Postcode = 3179.0
# *************************
#        Suburb  count
# 244  Scoresby      9
# --------------------------------------------------
# Postcode = 3180.0
# *************************
#         Suburb  count
# 245  Knoxfield     14
# --------------------------------------------------
# Postcode = 3181.0
# *************************
#       Suburb  count
# 246  Prahran    156
# 247  Windsor     63
# --------------------------------------------------
# Postcode = 3182.0
# *************************
#        Suburb  count
# 248  St Kilda    234
# --------------------------------------------------
# Postcode = 3183.0
# *************************
#         Suburb  count
# 249  Balaclava     47
# --------------------------------------------------
# Postcode = 3184.0
# *************************
#      Suburb  count
# 250  Elwood    162
# --------------------------------------------------
# Postcode = 3185.0
# *************************
#           Suburb  count
# 251  Elsternwick     77
# 252   Gardenvale     10
# 253    Ripponlea     12
# --------------------------------------------------
# Postcode = 3186.0
# *************************
#        Suburb  count
# 254  Brighton    254
# --------------------------------------------------
# Postcode = 3187.0
# *************************
#             Suburb  count
# 255  Brighton East    213
# --------------------------------------------------
# Postcode = 3188.0
# *************************
#            Suburb  count
# 256       Hampton    179
# 257  Hampton East     67
# --------------------------------------------------
# Postcode = 3189.0
# *************************
#         Suburb  count
# 258  Moorabbin     88
# --------------------------------------------------
# Postcode = 3190.0
# *************************
#       Suburb  count
# 259  Highett     69
# --------------------------------------------------
# Postcode = 3191.0
# *************************
#           Suburb  count
# 260  Sandringham     59
# --------------------------------------------------
# Postcode = 3192.0
# *************************
#          Suburb  count
# 261  Cheltenham    120
# --------------------------------------------------
# Postcode = 3193.0
# *************************
#          Suburb  count
# 262   Beaumaris     69
# 263  Black Rock     19
# --------------------------------------------------
# Postcode = 3194.0
# *************************
#       Suburb  count
# 264  Mentone     74
# --------------------------------------------------
# Postcode = 3195.0
# *************************
#                 Suburb  count
# 265          Aspendale     25
# 266  Aspendale Gardens     10
# 267         Mordialloc     46
# 268           Parkdale     62
# 269          Waterways      1
# --------------------------------------------------
# Postcode = 3196.0
# *************************
#               Suburb  count
# 270         Bonbeach     10
# 271          Chelsea     26
# 272  Chelsea Heights     14
# 273        Edithvale     25
# --------------------------------------------------
# Postcode = 3197.0
# *************************
#               Suburb  count
# 274           Carrum     21
# 275  Patterson Lakes      5
# --------------------------------------------------
# Postcode = 3198.0
# *************************
#       Suburb  count
# 276  Seaford     34
# --------------------------------------------------
# Postcode = 3199.0
# *************************
#               Suburb  count
# 277        Frankston     71
# 278  Frankston South     34
# --------------------------------------------------
# Postcode = 3200.0
# *************************
#               Suburb  count
# 279  Frankston North     13
# --------------------------------------------------
# Postcode = 3201.0
# *************************
#            Suburb  count
# 280  Carrum Downs     20
# --------------------------------------------------
# Postcode = 3202.0
# *************************
#          Suburb  count
# 281  Heatherton      2
# --------------------------------------------------
# Postcode = 3204.0
# *************************
#         Suburb  count
# 282  Bentleigh    223
# 283   McKinnon     22
# 284     Ormond    102
# --------------------------------------------------
# Postcode = 3205.0
# *************************
#               Suburb  count
# 285  South Melbourne    118
# --------------------------------------------------
# Postcode = 3206.0
# *************************
#           Suburb  count
# 286  Albert Park     79
# 287  Middle Park     45
# --------------------------------------------------
# Postcode = 3207.0
# *************************
#              Suburb  count
# 288  Port Melbourne    214
# --------------------------------------------------
# Postcode = 3335.0
# *************************
#        Suburb  count
# 289  Plumpton      6
# 290  Rockbank      3
# --------------------------------------------------
# Postcode = 3337.0
# *************************
#           Suburb  count
# 291    Kurunjang     13
# 292       Melton     25
# 293  Melton West     26
# --------------------------------------------------
# Postcode = 3338.0
# *************************
#            Suburb  count
# 294    Brookfield      3
# 295  Melton South     42
# --------------------------------------------------
# Postcode = 3340.0
# *************************
#             Suburb  count
# 296  Bacchus Marsh      3
# 297         Darley      1
# --------------------------------------------------
# Postcode = 3427.0
# *************************
#            Suburb  count
# 298  Diggers Rest      6
# --------------------------------------------------
# Postcode = 3428.0
# *************************
#     Suburb  count
# 299  Bulla      1
# --------------------------------------------------
# Postcode = 3429.0
# *************************
#       Suburb  count
# 300  Sunbury    112
# --------------------------------------------------
# Postcode = 3431.0
# *************************
#              Suburb  count
# 301  Riddells Creek      1
# --------------------------------------------------
# Postcode = 3437.0
# *************************
#              Suburb  count
# 302    Bullengarook      4
# 303        Gisborne     19
# 304  Gisborne South      2
# --------------------------------------------------
# Postcode = 3438.0
# *************************
#            Suburb  count
# 305  New Gisborne      3
# --------------------------------------------------
# Postcode = 3750.0
# *************************
#       Suburb  count
# 306  Wollert     39
# --------------------------------------------------
# Postcode = 3752.0
# *************************
#            Suburb  count
# 307  South Morang     71
# --------------------------------------------------
# Postcode = 3754.0
# *************************
#      Suburb  count
# 308  Doreen     28
# 309  Mernda     66
# --------------------------------------------------
# Postcode = 3756.0
# *************************
#      Suburb  count
# 310  Wallan      8
# --------------------------------------------------
# Postcode = 3757.0
# *************************
#          Suburb  count
# 311  Whittlesea      4
# --------------------------------------------------
# Postcode = 3775.0
# *************************
#          Suburb  count
# 312  Yarra Glen      1
# --------------------------------------------------
# Postcode = 3777.0
# *************************
#           Suburb  count
# 313  Healesville      1
# --------------------------------------------------
# Postcode = 3782.0
# *************************
#       Suburb  count
# 314  Emerald      3
# --------------------------------------------------
# Postcode = 3786.0
# *************************
#           Suburb  count
# 315  Ferny Creek      1
# --------------------------------------------------
# Postcode = 3793.0
# *************************
#       Suburb  count
# 316  Monbulk      1
# --------------------------------------------------
# Postcode = 3795.0
# *************************
#      Suburb  count
# 317  Silvan      2
# --------------------------------------------------
# Postcode = 3796.0
# *************************
#            Suburb  count
# 318  Mount Evelyn      3
# --------------------------------------------------
# Postcode = 3802.0
# *************************
#               Suburb  count
# 319  Endeavour Hills     16
# --------------------------------------------------
# Postcode = 3803.0
# *************************
#      Suburb  count
# 320  Hallam      7
# --------------------------------------------------
# Postcode = 3805.0
# *************************
#            Suburb  count
# 321  Narre Warren     14
# --------------------------------------------------
# Postcode = 3806.0
# *************************
#       Suburb  count
# 322  Berwick     34
# --------------------------------------------------
# Postcode = 3807.0
# *************************
#            Suburb  count
# 323  Beaconsfield      2
# --------------------------------------------------
# Postcode = 3808.0
# *************************
#                  Suburb  count
# 324  Beaconsfield Upper      2
# --------------------------------------------------
# Postcode = 3809.0
# *************************
#       Suburb  count
# 325  Officer      3
# --------------------------------------------------
# Postcode = 3810.0
# *************************
#        Suburb  count
# 326  Pakenham     10
# --------------------------------------------------
# Postcode = 3910.0
# *************************
#          Suburb  count
# 327  Langwarrin     14
# --------------------------------------------------
# Postcode = 3975.0
# *************************
#        Suburb  count
# 328  Lynbrook      2
# --------------------------------------------------
# Postcode = 3976.0
# *************************
#            Suburb  count
# 329  Hampton Park      5
# --------------------------------------------------
# Postcode = 3977.0
# *************************
#                Suburb  count
# 330        Cranbourne      9
# 331   Cranbourne East      1
# 332  Cranbourne North      3
# 333   Cranbourne West      4
# 334         Sandhurst      1
# 335              Skye      3
# --------------------------------------------------
# Postcode = 3978.0
# *************************
#           Suburb  count
# 336  Clyde North      3
# --------------------------------------------------

# %% [markdown]
# * Is Postalcode an important feature in predicting Price ?

# %%
gr = sns.catplot(data=training_set, x="Postcode", y="Price", kind="bar", ci=None,height=10, aspect=5)
plt.xlabel("Postcode")
plt.ylabel("Average Price")
l1 = gr.set_yticklabels(rotation = 45)
l2 = gr.set_xticklabels(rotation = 45)

# %%
gr = sns.catplot(data=training_set, x="Suburb", y="Price", kind="bar", ci=None,height=10, aspect=5)
plt.xlabel("Suburb")
plt.ylabel("Average Price")
l1 = gr.set_yticklabels(rotation = 45)
l2 = gr.set_xticklabels(rotation = 45)

# %% [markdown]
# - Drop "CouncilArea", "Regionname", "Lattitude", "Suburb", "Longtitude"

# %%
training_set.drop(["CouncilArea", "Regionname", "Lattitude", "Suburb", "Longtitude","Address"],axis=1, inplace=True)

# %%
training_set.columns
# Out:
# Index(['Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date', 'Distance',
#        'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea',
#        'YearBuilt', 'Propertycount'],
#       dtype='object')

# %%
training_set.head(4)
# Out:
#        Rooms Type      Price Method SellerG        Date  Distance  Postcode  \
# 17957      2    u   580000.0     VB  Nelson  26/08/2017       4.0    3057.0
# 6753       3    t  1025000.0     SP  Jellis   3/12/2016       2.6    3121.0
# 1833       2    t   380000.0     VB  Nelson   7/11/2016       5.9    3055.0
# 19795      2    u   456000.0      S    Brad  21/10/2017       8.5    3044.0
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 17957       2.0       1.0  1.0       NaN          61.0     1970.0
# 6753        NaN       NaN  NaN       NaN           NaN        NaN
# 1833        2.0       1.0  1.0       0.0          85.0     1970.0
# 19795       NaN       NaN  NaN       NaN           NaN        NaN
#
#        Propertycount
# 17957         5533.0
# 6753         14949.0
# 1833          7082.0
# 19795         7485.0

# %%
training_set.select_dtypes(['object']).isnull().any()
# Out:
# Type       False
# Method     False
# SellerG    False
# Date       False
# dtype: bool

# %% [markdown]
# * Date field has got date in string format,
# I think it is good to extract sold year as we have YearBuilt in the dataset

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
training_set.Date = pd.to_datetime(training_set.Date)

# %%
training_set["sold_year"] = training_set.Date.apply(lambda x: x.year)

# %%
training_set.drop("Date", axis=1, inplace=True)

# %% [markdown]
# ### EDA (Statistical data analysis) of numerical columns and fixing problems.

# %%
training_set.select_dtypes(['float64','int64']).isnull().any()
# Out:
# Rooms            False
# Price            False
# Distance         False
# Postcode         False
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# Propertycount     True
# sold_year        False
# dtype: bool

# %%
training_set[training_set.Bedroom2.isnull()].shape
# Out:
# (5163, 15)

# %% [markdown]
# - Bedroom2

# %%
training_set.Bedroom2.hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  Filling null values with the mean as it is contineous data

# %%
training_set.Bedroom2.fillna(value=training_set.Bedroom2.mean(), inplace=True)

# %% [markdown]
# - Bathroom

# %%
training_set[training_set.Bathroom.isnull()].shape
# Out:
# (5169, 15)

# %%
training_set.Bathroom.hist(bins=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Filling null values with mode as it is categorical data.

# %%
training_set.Bathroom.mode()[0]
# Out:
# 1.0

# %%
training_set.Bathroom.fillna(value=training_set.Bathroom.mode()[0], inplace=True)

# %%
training_set[training_set.Bathroom.isnull()].shape
# Out:
# (0, 15)

# %% [markdown]
# - Car

# %%
training_set[training_set.Car.isnull()].shape
# Out:
# (5472, 15)

# %%
training_set.Car.hist(bins=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Filling null values with median as it is Categorical data

# %%
training_set.Car.fillna(value=training_set.Car.median(), inplace=True)

# %%
training_set[training_set.Car.isnull()].shape
# Out:
# (0, 15)

# %% [markdown]
# - Landsize

# %%
training_set[training_set.Landsize.isnull()].shape
# Out:
# (7443, 15)

# %%
training_set.Landsize.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
training_set.Landsize.describe()
# Out:
# count     14353.000000
# mean        570.962447
# std        1956.911573
# min           0.000000
# 25%         220.000000
# 50%         513.000000
# 75%         664.000000
# max      146699.000000
# Name: Landsize, dtype: float64

# %%
training_set[training_set.Landsize == 0].shape
# Out:
# (1540, 15)

# %%
training_set[training_set.Landsize > 656].shape
# Out:
# (3778, 15)

# %%
training_set[training_set.Landsize < 2191].shape
# Out:
# (14159, 15)

# %%
training_set[training_set.Landsize < 0].shape
# Out:
# (0, 15)

# %%
training_set[~training_set.Landsize.isnull() & training_set.Landsize > 0].shape
# Out:
# (12813, 15)

# %%
training_set["Landsize_log"] = np.log(training_set[~training_set.Landsize.isnull() & training_set.Landsize > 0]['Landsize'])

# %%
training_set["Landsize_log"].describe()
# Out:
# count    12813.000000
# mean         6.127162
# std          0.705189
# min          0.000000
# 25%          5.717028
# 50%          6.315358
# 75%          6.530878
# max         11.896138
# Name: Landsize_log, dtype: float64

# %%
training_set["Landsize_log"].hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
Landsize_log_mean = training_set["Landsize_log"].mean()
training_set["Landsize_log"].fillna(value=Landsize_log_mean, inplace=True)
training_set["Landsize_log"] = training_set["Landsize_log"].apply(lambda x: Landsize_log_mean if x ==0 else x)

# %%
training_set.drop('Landsize', axis=1, inplace=True)

# %%
training_set.fillna(value= training_set.mean()[["BuildingArea", "YearBuilt", "Propertycount"]], inplace=True)

# %%
training_set.isnull().any()
# Out:
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Distance         False
# Postcode         False
# Bedroom2         False
# Bathroom         False
# Car              False
# BuildingArea     False
# YearBuilt        False
# Propertycount    False
# sold_year        False
# Landsize_log     False
# dtype: bool

# %%
training_set.dtypes
# Out:
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# BuildingArea     float64
# YearBuilt        float64
# Propertycount    float64
# sold_year          int64
# Landsize_log     float64
# dtype: object

# %% [markdown]
# ### Interested in knowing more about catagorical/text columns. Once after analysis we have to convert the data to numerical.
#
# - Before we convert catagorical data to numbers, we must see if there is any effect of the "individual catagories" on the mean of the target variable.
# - Example if there are 10 houses beloning to Method "S", 100 houses belonging to Method "SP".
# Total Price of "S" houses in 100000, Total Price of "SP" houses is 1000000. The avarage (mean) Price of "S" and "SP" houses is same - 10000. That means "statistically" there is no direct effect of Method "S", "SP" on Price variable (note: in business point of view, there might be an effect. Need to check statistical understanding with business analyst). In this scenario we should go with One-Hot-Encoding or Dummy Variable creation. Otherwise we can go with Label Encoding.

# %%
training_set.select_dtypes(['object']).columns
# Out:
# Index(['Type', 'Method', 'SellerG'], dtype='object')

# %%
training_set['Method'].value_counts()
# Out:
# S     13955
# SP     2882
# PI     2626
# VB     2178
# SA      155
# Name: Method, dtype: int64

# %% [markdown]
# #### Is there a significant effect of different categories in Method on Price

# %%
training_set.groupby(['Method'])['Price'].mean()
# Out:
# Method
# PI    1.122780e+06
# S     1.049267e+06
# SA    9.966541e+05
# SP    8.802131e+05
# VB    1.193416e+06
# Name: Price, dtype: float64

# %%
sns.catplot(data=training_set, x="Method", y="Price", kind="bar", ci=None)
plt.ylabel("Mean Price")
# Out:
# Text(9.444444444444445, 0.5, 'Mean Price')

# %% [markdown]
# #### Above visualization depects that there is a little difference in mean price for different catagories of Method. Need to do hypothesis testing to make sure that this holds true in population
#
# ANOVA: Tukey's Honestly Singnificant Difference test

# %%
import statsmodels.stats.multicomp as multi


mc1 = multi.MultiComparison(training_set["Price"],training_set["Method"])
res1 = mc1.tukeyhsd()
print(res1.summary())
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
# group1 group2   meandiff   p-adj     lower        upper     reject
# ------------------------------------------------------------------
#     PI      S  -73512.4251    0.0 -110262.0356  -36762.8145   True
#     PI     SA -126125.7769 0.1128 -268931.9387   16680.3849  False
#     PI     SP -242566.7525    0.0 -289174.9469  -195958.558   True
#     PI     VB   70636.5441 0.0011   20565.7057  120707.3825   True
#      S     SA  -52613.3518 0.8422 -192151.3215   86924.6179  False
#      S     SP -169054.3274    0.0 -204403.5697 -133705.0851   True
#      S     VB  144148.9692    0.0  104345.2759  183952.6625   True
#     SA     SP -116440.9756 0.1687 -258893.1953   26011.2441  False
#     SA     VB   196762.321 0.0017   53139.8994  340384.7425   True
#     SP     VB  313203.2966    0.0  264151.0396  362255.5535   True
# ------------------------------------------------------------------

# %% [markdown]
# Most of the pair wise ANOVA tests show that there is a significance "Price" difference for different catagories of "Method". Hence we can do LabelEncoding

# %%
lst_all_method_cats =['S', 'SP','PI','PN','SN','NB','VB','W','SA','SS','N/A']

# %%
training_set.Method =pd.Categorical(training_set.Method, categories=lst_all_method_cats)

# %%
training_set.Method.value_counts()
# Out:
# S      13955
# SP      2882
# PI      2626
# VB      2178
# SA       155
# PN         0
# SN         0
# NB         0
# W          0
# SS         0
# N/A        0
# Name: Method, dtype: int64

# %% [markdown]
# The data is unbalanced, need to make it look balanced by either Dummies/SMOTE

# %%
training_set =pd.get_dummies(training_set, columns=['Method'], prefix=['Method'], drop_first=True)

# %%
[col for col in training_set.columns if 'Method' in col ]
# Out:
# ['Method_SP',
#  'Method_PI',
#  'Method_PN',
#  'Method_SN',
#  'Method_NB',
#  'Method_VB',
#  'Method_W',
#  'Method_SA',
#  'Method_SS',
#  'Method_N/A']

# %%
training_set[[col for col in training_set.columns if 'Method' in col]].head()
# Out:
#        Method_SP  Method_PI  Method_PN  Method_SN  Method_NB  Method_VB  \
# 17957          0          0          0          0          0          1
# 6753           1          0          0          0          0          0
# 1833           0          0          0          0          0          1
# 19795          0          0          0          0          0          0
# 17054          0          0          0          0          0          0
#
#        Method_W  Method_SA  Method_SS  Method_N/A
# 17957         0          0          0           0
# 6753          0          0          0           0
# 1833          0          0          0           0
# 19795         0          0          0           0
# 17054         0          0          0           0

# %%
training_set['Type'].value_counts()
# Out:
# h    14781
# u     4733
# t     2282
# Name: Type, dtype: int64

# %% [markdown]
# - Type

# %%
training_set.groupby(['Type'])['Price'].mean()
# Out:
# Type
# h    1.203264e+06
# t    9.375948e+05
# u    6.246408e+05
# Name: Price, dtype: float64

# %% [markdown]
# We see significant difference, hence we can go with Label Encoding

# %%
training_set['Type'] = pd.Categorical(training_set['Type'])
training_set['Type'] = training_set['Type'].cat.codes
training_set['Type'].value_counts()
# Out:
# 0    14781
# 2     4733
# 1     2282
# Name: Type, dtype: int64

# %% [markdown]
# - SellerG

# %%
training_set['SellerG'].value_counts().shape
# Out:
# (330,)

# %% [markdown]
# #### Check the behaviour of the top sellers.

# %%
top_sellers = list(training_set['SellerG'].value_counts()[training_set['SellerG'].value_counts().values > 100].index)

# %%
print(top_sellers)
# Out:
# ['Nelson', 'Jellis', 'Barry', 'hockingstuart', 'Ray', 'Buxton', 'Marshall', 'Biggin', 'Fletchers', 'Brad', 'Woodards', 'McGrath', 'Greg', 'YPA', 'Noel', 'Jas', 'Stockdale', 'Miles', 'Sweeney', 'RT', 'Harcourts', 'Gary', 'Hodges', 'Raine', 'HAR', 'Love', 'RW', 'Kay', "O'Brien", 'Williams', 'Village', 'Douglas', 'C21', 'Chisholm', 'Purplebricks']

# %%
top_sellers_train_set = training_set[training_set['SellerG'].isin(top_sellers)]

# %%
top_sel = sns.catplot(data=top_sellers_train_set, x="SellerG", y="Price", kind="bar", height=10, ci=None)
plt.ylabel("Mean Price")
l1 = top_sel.set_yticklabels(rotation = 50)
l2 = top_sel.set_xticklabels(rotation = 50)

# %% [markdown]
# We see significant difference, hence we can go with Label Encoding

# %%
training_set['SellerG'] = pd.Categorical(training_set['SellerG'])
training_set['SellerG'] = training_set['SellerG'].cat.codes
training_set['SellerG'].value_counts().head()
# Out:
# 199    2174
# 138    2047
# 21     1919
# 319    1694
# 245    1263
# Name: SellerG, dtype: int64

# %% [markdown]
# ## Now data is ready, lets build a Linear Regression model with SGDRegressor

# %%
training_set.dtypes
# Out:
# Rooms              int64
# Type                int8
# Price            float64
# SellerG            int16
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# BuildingArea     float64
# YearBuilt        float64
# Propertycount    float64
# sold_year          int64
# Landsize_log     float64
# Method_SP          uint8
# Method_PI          uint8
# Method_PN          uint8
# Method_SN          uint8
# Method_NB          uint8
# Method_VB          uint8
# Method_W           uint8
# Method_SA          uint8
# Method_SS          uint8
# Method_N/A         uint8
# dtype: object

# %%
input_features = [x for x in training_set.columns if x not in ['Price']]

# %%
input_features
# Out:
# ['Rooms',
#  'Type',
#  'SellerG',
#  'Distance',
#  'Postcode',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'BuildingArea',
#  'YearBuilt',
#  'Propertycount',
#  'sold_year',
#  'Landsize_log',
#  'Method_SP',
#  'Method_PI',
#  'Method_PN',
#  'Method_SN',
#  'Method_NB',
#  'Method_VB',
#  'Method_W',
#  'Method_SA',
#  'Method_SS',
#  'Method_N/A']

# %%
X_train = training_set[input_features].values
y_train = training_set['Price'].values

# %%
lr = LinearRegression()

lr_model = lr.fit(X_train, y_train)

# %%
y_train_pred = lr_model.predict(X_train)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_train, y_train_pred)
print(r2)
# Out:
# 0.48467536024042435

# %% [markdown]
# ### Error analysis and finetuning the model

# %%
residuals = y_train - y_train_pred

# %%
def standard_scale(val):
    mean_vals = np.mean(val)
    std_vals = np.std(val)
    z_vals = [(x - mean_vals)/std_vals for x in val]
    return z_vals

# %%
def plotScatterPlot(residuals, y):
    std_residuals = standard_scale(residuals)
    std_predicted = standard_scale(y)
    plt.scatter(std_predicted, std_residuals, alpha = 0.6, color='y')
    l = plt.axhline(y=0, color='r')
    plt.xlabel('STD Predicted values')
    plt.ylabel('STD Residual values')
    plt.axis([-6, 6, -10, 10])
    plt.show()

# %% [markdown]
# ### plotScatterPlot(residuals, y_train_pred)

# %%
plotScatterPlot(residuals, y_train_pred)

# %% [markdown]
# ### We found heteroscedasticity in the dataset, one of the solution is the apply log transormation on y variable, build model. Let's try that.

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
y_train_log = np.log(y_train)

# %%
lr_model = lr_model.fit(X_train, y_train_log)

# %%
y_train_log_pred = lr_model.predict(X_train)

# %%
r2 = r2_score(y_train_log, y_train_log_pred)
print(r2)
# Out:
# 0.5775719437885163

# %%
res = y_train_log - y_train_log_pred

# %%
plotScatterPlot(res, y_train_log_pred)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbrt = GradientBoostingRegressor(max_depth=4, n_estimators=300, learning_rate=0.1, random_state=42)
gbrt.fit(X_train, y_train)
y_pred_gbrt = gbrt.predict(X_train)

# %%
r2 = r2_score(y_train, y_pred_gbrt)
print(r2)
# Out:
# 0.8431136902758644

# %% [markdown]
# ### Apply model on TEST set and finetune model

# %%
test_set = test_set.drop(test_set[test_set['Postcode'].isnull()].index)

test_set.drop(["Address", "CouncilArea", "Regionname", "Lattitude", "Suburb", "Longtitude"], axis=1, inplace=True)

test_set.Date = pd.to_datetime(test_set.Date)
test_set["sold_year"] = test_set.Date.apply(lambda x: x.year)
test_set.drop("Date", axis=1, inplace=True)

test_set.Bedroom2.fillna(value=test_set.Bedroom2.mean(), inplace=True)
test_set.Bathroom.fillna(value=test_set.Bathroom.mean(), inplace=True)
test_set.Car.fillna(value=test_set.Car.median(), inplace=True)

test_set["Landsize_log"] = np.log(test_set[~test_set.Landsize.isnull() & test_set.Landsize > 0]['Landsize'])
Landsize_log_mean = test_set["Landsize_log"].mean()
test_set["Landsize_log"].fillna(value=Landsize_log_mean, inplace=True)
test_set["Landsize_log"] = test_set["Landsize_log"].apply(lambda x: Landsize_log_mean if x == 0 else x) 
test_set.drop('Landsize', axis=1, inplace=True)

test_set.fillna(value= test_set.mean()[["BuildingArea", "YearBuilt", "Propertycount"]], inplace=True)

lst_all_method_cats = ['S', 'SP','PI','PN','SN','NB','VB','W','SA','SS','N/A']
test_set.Method = pd.Categorical(test_set.Method, categories=lst_all_method_cats)
test_set = pd.get_dummies(test_set, columns=["Method"], prefix=["Method"], drop_first=True)

test_set['Type'] = pd.Categorical(test_set['Type'])
test_set['Type'] = test_set['Type'].cat.codes

test_set['SellerG'] = pd.Categorical(test_set['SellerG'])
test_set['SellerG'] = test_set['SellerG'].cat.codes

# %%
input_features = [x for x in training_set.columns if x not in ['Price']]

X_test = test_set[input_features].values
y_test = test_set['Price'].values

# %%
y_test_pred_gbrt = gbrt.predict(X_test)

# %%
r2 = r2_score(y_test, y_test_pred_gbrt)
print(r2)
# Out:
# 0.7510321188010318
